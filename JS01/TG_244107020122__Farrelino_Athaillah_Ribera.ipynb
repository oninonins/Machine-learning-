# %% [markdown]
# <a href="https://colab.research.google.com/github/oninonins/Machine-learning-/blob/main/JS1/TG_244107020122__Farrelino_Athaillah_Ribera.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyprep scipy wandb pyecg
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 7.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %% [markdown]
# Library
# PyPREP : Preprocessing dan cleaning data EEG. Digunakan untuk mengurangi noise/artifact pada sinyal EEG sebelum dianalisis lebih lanjut
# SciPy	: Library scientific computing Python. Menyediakan fungsi untuk signal processing, statistik, optimasi, interpolasi, filtering, dan operasi numerik lainnya
# wandb :	Digunakan untuk tracking eksperimen machine learning: mencatat loss, accuracy, hyperparameter, model, grafik training, dan membandingkan beberapa eksperimen.
# PyECG	: pemrosesan dan analisis sinyal elektrokardiogram.

# %%
# !pip install scikit-learn

# %%
# !pip install pyecg --no-deps
# Out:
# ...
#   Using cached pyECG-0.0.9.1-py2.py3-none-any.whl.metadata (3.1 kB)
# ...

# %% [markdown]
# Bagian 2
# 1. Berikan contoh tentang tidakan melanggar etika dan hukum tentang penggunaan kecerdasan buatan. Sertakan referensi yang digunakan.
#
# memakai deepfake dan membuat hoax
# ref
#  Federal Trade Commission. Federal Trade Commission Announces Final Rule Banning Fake Reviews and Testimonials.
#
# 2. Berikan contoh tentang dampak energi dan lingkungan terhadap pemanfaatan kecerdasan buatan dan bagaimana cara mengatasinya (Anda dapat memberikan pendapat pribadi). Sertakan referensi yang digunakan.
#
#
# dampaknya adalah konsumsi listrik yang tinggi dan juga butuh air untuk pendinginan
# menurut saya kita ketika menggunakan ai gunakan untuk keperluan yang membutuhkan nalar tinggi dan brainstrorming
# jadi untuk tugas seharu2 tidak usah
# ref
# International Energy Agency (IEA). Energy and AI. 2025.
